# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot()
# Out:
# []

# %%
plt.plot();

# %%
plt.plot()
plt.show()

# %%
plt.plot([1,2,3,4]);

# %%
plt.plot([1,2,3,4],[1,6,2,8]);
# plot showing when x = 1 y = 1, x = 2 y = 6

# %%
x = [1,2,3,4]
y = [11,2,33,44]
plt.plot(x,y);

# %%
# 1st method
fig = plt.figure() # creates a figure
ax = fig.add_subplot()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# 2nd method
fig = plt.figure() # creates a figure
ax = fig.add_axes([1,1,1,1])
ax.plot(x,y) # add exicting data of x and y mentioned above
plt.show()

# %%
# 3rd method (recommended)  moslty we use this method only
# (In general, try to use the object-oriented interface over the pyplot interface)
fig, ax =  plt.subplots()
ax.plot(x, y); # using existing data

# %%
# 3rd method (recommended)  moslty we use this method only
# (In general, try to use the object-oriented interface over the pyplot interface)
fig, ax =  plt.subplots()
ax.plot([1,2,3,4], [50, 100, 200, 250]);

# %%
# some randome example
x = np.linspace(0, 2*np.pi, 400)
y = np.sin(x**2)
# Create just a figure and only one subplot
fig, ax = plt.subplots()
ax.plot(x, y)
ax.set_title('Simple plot')
# Out:
# Text(0.5, 1.0, 'Simple plot')

# %% [markdown]
# ## Matplotlib example workflow

# %%
# 0. Import matplotlib and get it ready for plotting in Jupyter
# %matplotlib inline
import matplotlib.pyplot as plt

# 1. Prepare data
x = [1,2,3,4]
y = [11,22,33,44]

# 2. Setup plot
fig, ax = plt.subplots(figsize=(10,10)) # (width, height)

# 3. Plot data
ax.plot(x,y)

# 4. Customize plot
ax.set(title="Simple Plot",
      xlabel="x-axis",
      ylabel="y-axis")

# 5. Save & show 
fig.savefig("/Language/chints/Machine Learning And Data Science/sample_plot.png")

# %% [markdown]
# ## Making figures with NumPy arrays
#
# We want:
# * Line plot
# * Scatter plot
# * Bar plot
# * Histogram
# * Subplot

# %%
# Create some data
x = np.linspace(0, 10, 100)
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
# Plot the data and create line plot (fig = figure, ax = axis)
fig, ax = plt.subplots()
ax.plot(x,x**2);

# %%
# Use same data to create a scatter plot
fig, ax = plt.subplots()
ax.scatter(x, np.exp(x));

# %%
np.exp(x)
# Out:
# array([1.00000000e+00, 1.10628782e+00, 1.22387273e+00, 1.35395549e+00,
#        1.49786447e+00, 1.65706921e+00, 1.83319548e+00, 2.02804182e+00,
#        2.24359796e+00, 2.48206508e+00, 2.74587836e+00, 3.03773178e+00,
#        3.36060565e+00, 3.71779709e+00, 4.11295363e+00, 4.55011049e+00,
#        5.03373179e+00, 5.56875615e+00, 6.16064708e+00, 6.81544881e+00,
#        7.53984798e+00, 8.34124196e+00, 9.22781435e+00, 1.02086186e+01,
#        1.12936704e+01, 1.24940499e+01, 1.38220152e+01, 1.52911270e+01,
#        1.69163875e+01, 1.87143934e+01, 2.07035054e+01, 2.29040358e+01,
#        2.53384558e+01, 2.80316249e+01, 3.10110451e+01, 3.43071414e+01,
#        3.79535725e+01, 4.19875748e+01, 4.64503425e+01, 5.13874480e+01,
#        5.68493076e+01, 6.28916963e+01, 6.95763174e+01, 7.69714323e+01,
#        8.51525577e+01, 9.42032371e+01, 1.04215893e+02, 1.15292773e+02,
#        1.27546990e+02, 1.41103681e+02, 1.56101284e+02, 1.72692948e+02,
# ...

# %%
# Another scatter plot
fig, ax = plt.subplots()
ax.scatter(x, np.sin(x));

# %%
np.sin(x)
# Out:
# array([ 0.        ,  0.10083842,  0.20064886,  0.2984138 ,  0.39313661,
#         0.48385164,  0.56963411,  0.64960951,  0.72296256,  0.78894546,
#         0.84688556,  0.8961922 ,  0.93636273,  0.96698762,  0.98775469,
#         0.99845223,  0.99897117,  0.98930624,  0.96955595,  0.93992165,
#         0.90070545,  0.85230712,  0.79522006,  0.73002623,  0.65739025,
#         0.57805259,  0.49282204,  0.40256749,  0.30820902,  0.21070855,
#         0.11106004,  0.01027934, -0.09060615, -0.19056796, -0.28858706,
#        -0.38366419, -0.47483011, -0.56115544, -0.64176014, -0.7158225 ,
#        -0.7825875 , -0.84137452, -0.89158426, -0.93270486, -0.96431712,
#        -0.98609877, -0.99782778, -0.99938456, -0.99075324, -0.97202182,
#        -0.94338126, -0.90512352, -0.85763861, -0.80141062, -0.73701276,
#        -0.66510151, -0.58640998, -0.50174037, -0.41195583, -0.31797166,
#        -0.22074597, -0.12126992, -0.0205576 ,  0.0803643 ,  0.18046693,
# ...

# %%
#  Make a plot from dictionary

nut_butter_prices = {"Almond butter": 10,
                    "Peanut butter": 8,
                    "Cashew butter": 12}
fig, ax = plt.subplots()
ax.bar(nut_butter_prices.keys(), nut_butter_prices.values());
ax.set(title="Butter prices",
      xlabel="BUTTER",
      ylabel= "Prices ($)");

# %%
nut_butter_prices = {"Almond butter": 10,
                    "Peanut butter": 8,
                    "Cashew butter": 12}
fig, ax = plt.subplots()
ax.scatter(nut_butter_prices.keys(), nut_butter_prices.values());
ax.set(title="Butter prices",
      xlabel="BUTTER",
      ylabel= "Prices ($)");

# %%
fig, ax = plt.subplots()
ax.barh(list(nut_butter_prices.keys()), list(nut_butter_prices.values()));

# %%
# Make some data
x = np.random.randn(1000)
fig, ax = plt.subplots()
ax.hist(x);

# %% [markdown]
# ## Two optopn for subplots

# %%
# Subplot option 1
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2,
                                            ncols=2,
                                            figsize=(10,5))
# PLot to each different axis
ax1.plot(x, x/2);
ax2.scatter(np.random.random(10), np.random.random(10));
ax3.bar(nut_butter_prices.keys(), nut_butter_prices.values());
ax3.set(title="Butter prices",
      xlabel="BUTTER",
      ylabel= "Prices ($)");
ax4.hist(np.random.randn(1000));

# %%
# Subplot option 2
fig, ax = plt.subplots(nrows=2,
                      ncols=2,
                      figsize=(10,5))

# plot to each different index
ax[0, 0].plot(x, x/2);
ax[0, 1].scatter(np.random.random(10), np.random.random(10));
ax[1, 0].bar(nut_butter_prices.keys(), nut_butter_prices.values());
ax[1, 1].hist(np.random.randn(1000));

# %% [markdown]
# ### Plotting from pandas DataFrames

# %%
# make a dataframe
car_sales = pd.read_csv("car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
ts = pd.Series(np.random.randn(1000),
              index = pd.date_range('1/1/2020', periods=1000))
ts
# Out:
# 2020-01-01   -1.323680
# 2020-01-02    1.599440
# 2020-01-03    0.221274
# 2020-01-04    0.091408
# 2020-01-05   -0.266050
#                 ...
# 2022-09-22   -0.623871
# 2022-09-23   -1.433058
# 2022-09-24    0.221596
# 2022-09-25    0.568790
# 2022-09-26    0.013268
# Freq: D, Length: 1000, dtype: float64

# %%
ts.cumsum()
# Out:
# 2020-01-01    -1.323680
# 2020-01-02     0.275760
# 2020-01-03     0.497034
# 2020-01-04     0.588442
# 2020-01-05     0.322392
#                 ...
# 2022-09-22   -24.054659
# 2022-09-23   -25.487716
# 2022-09-24   -25.266121
# 2022-09-25   -24.697331
# 2022-09-26   -24.684063
# Freq: D, Length: 1000, dtype: float64

# %%
-0.488537-2.333406
# Out:
# -2.821943

# %% [markdown]
# #### How cumsum() works??
#
# If `column` is:
# * 1
# * 2
# * 3
# * 4
# * 5
#
# `column.cumsum()` should be:
# * 1
# * 3 (1 + 2)
# * 6 (3 + 3)
# * 10 (6 + 4)
# * 15 (10 +5)

# %%
a = np.random.randn(10)
a
# Out:
# array([ 1.22533618,  1.57238448,  1.15591939,  1.94965908,  1.43164927,
#         1.32624654, -1.48027995, -0.2361085 ,  0.7566549 , -0.82003625])

# %%
a.cumsum()
# Out:
# array([1.22533618, 2.79772066, 3.95364005, 5.90329913, 7.3349484 ,
#        8.66119494, 7.18091499, 6.94480648, 7.70146139, 6.88142514])

# %%
ts.cumsum().plot();

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# removing $ , and . with using regex 
car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]', '')
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
type(car_sales["Price"][0])
# Out:
# str

# %%
# remove last to zeros
car_sales["Price"] = car_sales["Price"].str[:-2]

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales["Sales Date"] = pd.date_range("1/1/2020", periods=len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price Sales Date
# 0  Toyota  White         150043      4   4000 2020-01-01
# 1   Honda    Red          87899      4   5000 2020-01-02
# 2  Toyota   Blue          32549      3   7000 2020-01-03
# 3     BMW  Black          11179      5  22000 2020-01-04
# 4  Nissan  White         213095      4   3500 2020-01-05
# 5  Toyota  Green          99213      4   4500 2020-01-06
# 6   Honda   Blue          45698      4   7500 2020-01-07
# 7   Honda   Blue          54738      4   7000 2020-01-08
# 8  Toyota  White          60000      4   6250 2020-01-09
# 9  Nissan  White          31600      4   9700 2020-01-10

# %%
car_sales["Total Sales"] = car_sales["Price"].cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price Sales Date  \
# 0  Toyota  White         150043      4   4000 2020-01-01
# 1   Honda    Red          87899      4   5000 2020-01-02
# 2  Toyota   Blue          32549      3   7000 2020-01-03
# 3     BMW  Black          11179      5  22000 2020-01-04
# 4  Nissan  White         213095      4   3500 2020-01-05
# 5  Toyota  Green          99213      4   4500 2020-01-06
# 6   Honda   Blue          45698      4   7500 2020-01-07
# 7   Honda   Blue          54738      4   7000 2020-01-08
# 8  Toyota  White          60000      4   6250 2020-01-09
# 9  Nissan  White          31600      4   9700 2020-01-10
#
#                                  Total Sales
# 0                                       4000
# 1                                   40005000
# 2                               400050007000
# 3                          40005000700022000
# 4                      400050007000220003500
# 5                  4000500070002200035004500
# ...

# %% [markdown]
# What happen above is cumsum() is worked but due to the type of Price column is string which gives us that output. str + str =strstr

# %%
# convert Price column datasype from str to int
car_sales["Total_Sales"] = car_sales["Price"].astype(int).cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price Sales Date  \
# 0  Toyota  White         150043      4   4000 2020-01-01
# 1   Honda    Red          87899      4   5000 2020-01-02
# 2  Toyota   Blue          32549      3   7000 2020-01-03
# 3     BMW  Black          11179      5  22000 2020-01-04
# 4  Nissan  White         213095      4   3500 2020-01-05
# 5  Toyota  Green          99213      4   4500 2020-01-06
# 6   Honda   Blue          45698      4   7500 2020-01-07
# 7   Honda   Blue          54738      4   7000 2020-01-08
# 8  Toyota  White          60000      4   6250 2020-01-09
# 9  Nissan  White          31600      4   9700 2020-01-10
#
#                                  Total Sales  Total_Sales
# 0                                       4000         4000
# 1                                   40005000         9000
# 2                               400050007000        16000
# 3                          40005000700022000        38000
# ...

# %%
# Let's plot te total sales
car_sales.plot(x="Sales Date", y="Total_Sales");

# %%
# Reassign price column to int
car_sales['Price'] = car_sales["Price"].astype(int)

# Plot scatter plot with price column as numeric
car_sales.plot(x="Odometer (KM)", y="Price", kind="scatter");

# %%
car_sales.plot(x="Odometer (KM)", y="Price", kind="bar");

# %%
car_sales.plot(x="Odometer (KM)", y="Price", kind="barh");

# %%
# Bar graph

x = np.random.rand(10, 4)

# turn it into DataFrame
df = pd.DataFrame(x, columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0  0.659541  0.771409  0.185809  0.319489
# 1  0.895254  0.669947  0.659438  0.231144
# 2  0.028849  0.732024  0.064989  0.856024
# 3  0.437598  0.891285  0.383084  0.672930
# 4  0.385022  0.229528  0.591335  0.929194
# 5  0.544187  0.021539  0.823193  0.105359
# 6  0.713893  0.366171  0.225527  0.449057
# 7  0.478816  0.207868  0.197980  0.026292
# 8  0.816181  0.703352  0.292982  0.847347
# 9  0.671418  0.557644  0.701717  0.256970

# %%
x
# Out:
# array([[0.65954125, 0.7714094 , 0.18580907, 0.31948854],
#        [0.89525395, 0.66994657, 0.65943757, 0.23114426],
#        [0.02884895, 0.73202445, 0.06498934, 0.85602426],
#        [0.43759779, 0.89128515, 0.38308352, 0.67293028],
#        [0.38502156, 0.22952804, 0.59133508, 0.92919426],
#        [0.54418725, 0.02153937, 0.82319287, 0.10535917],
#        [0.71389267, 0.36617067, 0.2255275 , 0.44905651],
#        [0.47881561, 0.20786773, 0.19797974, 0.02629172],
#        [0.81618056, 0.70335222, 0.29298196, 0.84734727],
#        [0.6714178 , 0.55764418, 0.70171688, 0.25696958]])

# %%
df.plot.bar();

# %%
# using kind gives same graph
df.plot(kind='bar');

# %%
# removed Total sales by pop, because it's str+str
car_sales.pop("Total Sales")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price Sales Date  Total_Sales
# 0  Toyota  White         150043      4   4000 2020-01-01         4000
# 1   Honda    Red          87899      4   5000 2020-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2020-01-03        16000
# 3     BMW  Black          11179      5  22000 2020-01-04        38000
# 4  Nissan  White         213095      4   3500 2020-01-05        41500
# 5  Toyota  Green          99213      4   4500 2020-01-06        46000
# 6   Honda   Blue          45698      4   7500 2020-01-07        53500
# 7   Honda   Blue          54738      4   7000 2020-01-08        60500
# 8  Toyota  White          60000      4   6250 2020-01-09        66750
# 9  Nissan  White          31600      4   9700 2020-01-10        76450

# %%
car_sales.plot(x="Make", y="Odometer (KM)", kind="bar");

# %%
# histograms

car_sales["Odometer (KM)"].plot.hist();

# %%
car_sales["Odometer (KM)"].plot(kind='hist');

# %%
car_sales["Odometer (KM)"].plot.hist(bins=20);

# %% [markdown]
# ### Try another dataset : Heart-disease

# %%
heart_disease = pd.read_csv("heart_disease.csv")
heart_disease.head(5)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_disease["age"].plot.hist(bins=10);

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_disease.plot.hist(figsize=(15,15),subplots=True);

# %% [markdown]
# ### Which one should use fro plotting?? (pyplot as above or OO Method{Object Oriented})
#
# * When plotting something quickly, it's okay to use the pyplot method
# * When plotting somtjingmore advanced, use the OO method.

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
over_50 = heart_disease[heart_disease['age'] > 50] 
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
# pyplot method
over_50.plot(kind="scatter",
            x='age',
            y='chol',
            c='target');

# %%
# OO method mixed with pyplot method

fig, ax = plt.subplots(figsize=(10,6))
over_50.plot(kind="scatter",
            x='age',
            y='chol',
            c='target',
            ax=ax);

# ax.set_xlim([45,100]);

# %%
## OO method from scratch
fig, ax = plt.subplots(figsize=(10,6))

# plot the data
scatter = ax.scatter(x=over_50["age"],
                    y=over_50["chol"],
                    c=over_50["target"]);

# customize the plot
ax.set(title="Heart disease and Cholestrol level",
      xlabel="Age",
      ylabel="Cholestrol");

# Add a legend
ax.legend(*scatter.legend_elements(), title="Target");

# Add a horizontal line
ax.axhline(over_50["chol"].mean(),
          linestyle='--');

# %%
# Subplot of chol, age, thalach(max heart rate)

fig, (ax0, ax1) = plt.subplots(nrows=2,
                              ncols=1,
                              figsize=(10,10),
                              sharex=True);

# Add data to ax0
scatter = ax0.scatter(x=over_50["age"],
                     y=over_50["chol"],
                     c=over_50["target"]);
# Customie ax0
ax0.set(title="Heart disease and Cholestrol Levels",
       ylabel="Cholestrol")
# Add a legend to ax0
ax0.legend(*scatter.legend_elements(), title="Target")
# Add a meanline
ax0.axhline(y=over_50["chol"].mean(),
           linestyle="--")


# Add data to ax1
scatter = ax1.scatter(x=over_50["age"],
                     y=over_50["thalach"],
                     c=over_50["target"]);
# customize ax1
ax1.set(title="Heart diesease and Max heart rate level",
       xlabel="Age",
       ylabel="Max herat Rate")
# Add a legend to ax1
ax1.legend(*scatter.legend_elements(), title="Target")
# Add a meanline
ax1.axhline(y=over_50["thalach"].mean(),
           linestyle='--');

# Add a title to figure
fig.suptitle("Heart Disease Analysis", fontsize=16, fontweight="bold");

# %% [markdown]
# ## Customizing Matplot lib plots and getting stylish

# %%
# See the different styles availble
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
car_sales["Price"].plot();

# %%
plt.style.use('seaborn-whitegrid')

# %%
car_sales["Price"].plot();

# %%
plt.style.use('seaborn')

# %%
car_sales['Price'].plot();

# %%
car_sales.plot(x="Odometer (KM)", y='Price', kind='scatter');

# %%
plt.style.use('ggplot')
car_sales["Price"].plot();

# %%
# CREATE SOME DATA
x = np.random.randn(10,4)
x
# Out:
# array([[-0.11595897, -0.86949869,  0.96718917, -0.37294231],
#        [ 0.52913005,  0.61570376,  0.07639112,  1.57098959],
#        [-0.3494056 , -0.67738853, -1.31969912, -0.27727138],
#        [ 2.00622701, -0.60521828,  0.02577236, -1.93218088],
#        [-0.24072603,  0.57557707, -0.10870788, -0.48467684],
#        [-1.56377122,  0.2262835 , -1.69301722,  0.71726618],
#        [ 0.49914875, -0.36816722,  0.32186386, -0.31123046],
#        [ 1.08178439, -0.0376099 ,  0.89859995,  0.92984064],
#        [ 0.32747659, -1.74980235, -0.22147922,  1.87873473],
#        [-1.86869299,  0.57914134,  0.93645029, -1.39885687]])

# %%
df = pd.DataFrame(x, columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0 -0.115959 -0.869499  0.967189 -0.372942
# 1  0.529130  0.615704  0.076391  1.570990
# 2 -0.349406 -0.677389 -1.319699 -0.277271
# 3  2.006227 -0.605218  0.025772 -1.932181
# 4 -0.240726  0.575577 -0.108708 -0.484677
# 5 -1.563771  0.226283 -1.693017  0.717266
# 6  0.499149 -0.368167  0.321864 -0.311230
# 7  1.081784 -0.037610  0.898600  0.929841
# 8  0.327477 -1.749802 -0.221479  1.878735
# 9 -1.868693  0.579141  0.936450 -1.398857

# %%
ax = df.plot(kind='bar')
type(ax);

# %%
# Customize our plot with the set() method
ax = df.plot(kind="bar")
# Ad some labels and title
ax.set(title='Random number bar graph from DataFrame',
      xlabel="Row Number",
      ylabel="Random Number")
# Make legend visible
ax.legend().set_visible(True)

# %%
# Set the style
plt.style.use('seaborn-whitegrid')

## OO method from scratch
fig, ax = plt.subplots(figsize=(10,6))

# plot the data
scatter = ax.scatter(x=over_50["age"],
                    y=over_50["chol"],
                    c=over_50["target"],
                    cmap="winter"); # this changes the color scheme

# customize the plot
ax.set(title="Heart disease and Cholestrol level",
      xlabel="Age",
      ylabel="Cholestrol");

# Add a legend
ax.legend(*scatter.legend_elements(), title="Target");

# Add a horizontal line
ax.axhline(over_50["chol"].mean(),
          linestyle='--');

# %%
# Customizing the y and x axis limitations
# Subplot of chol, age, thalach(max heart rate)

fig, (ax0, ax1) = plt.subplots(nrows=2,
                              ncols=1,
                              figsize=(10,10),
                              sharex=True);

# Add data to ax0
scatter = ax0.scatter(x=over_50["age"],
                     y=over_50["chol"],
                     c=over_50["target"],
                     cmap='winter');
# Customie ax0
ax0.set(title="Heart disease and Cholestrol Levels",
       ylabel="Cholestrol")
# change the x axis limit
ax0.set_xlim([50,80]) 
# Add a legend to ax0
ax0.legend(*scatter.legend_elements(), title="Target")
# Add a meanline
ax0.axhline(y=over_50["chol"].mean(),
           linestyle="--")


# Add data to ax1
scatter = ax1.scatter(x=over_50["age"],
                     y=over_50["thalach"],
                     c=over_50["target"],
                     cmap='winter');
# customize ax1
ax1.set(title="Heart diesease and Max heart rate level",
       xlabel="Age",
       ylabel="Max herat Rate")
# change the y axis limits, not require to set limit again for x because it's sharing with ax0 it's same
ax1.set_ylim([60,200])
# Add a legend to ax1
ax1.legend(*scatter.legend_elements(), title="Target")
# Add a meanline
ax1.axhline(y=over_50["thalach"].mean(),
           linestyle='--');

# Add a title to figure
fig.suptitle("Heart Disease Analysis", fontsize=16, fontweight="bold");

# %%
fig

# %%
fig.savefig("Heart-disease-analysis.png")
